# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv('My Uber Drives - 2016.csv')

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
# START_DATE*    1156 non-null object
# END_DATE*      1155 non-null object
# CATEGORY*      1155 non-null object
# START*         1155 non-null object
# STOP*          1155 non-null object
# MILES*         1156 non-null float64
# PURPOSE*       653 non-null object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %% [markdown]
# ## Removing the last row.

# %%
df1=df.iloc[:-1,:]

# %%
df1.describe(include='all')
# Out:
#             START_DATE*        END_DATE* CATEGORY* START* STOP*       MILES*  \
# count              1155             1155      1155   1155  1155  1155.000000
# unique             1154             1154         2    177   188          NaN
# top     6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary          NaN
# freq                  2                2      1078    201   203          NaN
# mean                NaN              NaN       NaN    NaN   NaN    10.566840
# std                 NaN              NaN       NaN    NaN   NaN    21.579106
# min                 NaN              NaN       NaN    NaN   NaN     0.500000
# 25%                 NaN              NaN       NaN    NaN   NaN     2.900000
# 50%                 NaN              NaN       NaN    NaN   NaN     6.000000
# 75%                 NaN              NaN       NaN    NaN   NaN    10.400000
# max                 NaN              NaN       NaN    NaN   NaN   310.300000
#
#        PURPOSE*
# count       653
# ...

# %%
df1.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*        PURPOSE*
# 1150           Kar?chi     0.7         Meeting
# 1151  Unknown Location     3.9  Temporary Site
# 1152  Unknown Location    16.2         Meeting
# 1153           Gampaha     6.4  Temporary Site
# 1154         Ilukwatta    48.2  Temporary Site

# %%
df1.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %% [markdown]
# ## Inserting a column named 'count'.

# %%
df1['count']=1
# Out:
# C:\Users\danie\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*  count
# 0          Fort Pierce     5.1   Meal/Entertain      1
# ...

# %%
df1['count'].sum()
# Out:
# 1155

# %%
df2=df1.copy()

# %% [markdown]
# ## Relationship between miles and the no. of bookings(i.e the count)
# Different categories of the miles have been created such as '0-5','5-10','10-15','15-20','20+'. We are to see the counts in each category and compare them.

# %%
miles=df2[['MILES*','count']]

# %%
miles
# Out:
#       MILES*  count
# 0        5.1      1
# 1        5.0      1
# 2        4.8      1
# 3        4.7      1
# 4       63.7      1
# ...      ...    ...
# 1150     0.7      1
# 1151     3.9      1
# 1152    16.2      1
# 1153     6.4      1
# 1154    48.2      1
#
# [1155 rows x 2 columns]

# %%
miles_list=['0-5','5-10','10-15','15-20','20+']

# %%
miles_count=[]

# %%
miles_lt5=df2.loc[(df1['MILES*'])<=5]

# %%
miles_lt5
# Out:
#            START_DATE*         END_DATE* CATEGORY*           START*  \
# 1        1/2/2016 1:25     1/2/2016 1:37  Business      Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business      Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business      Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business  West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business             Cary
# ...                ...               ...       ...              ...
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business          Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business          Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business          Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business          Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business          Kar?chi
#
#                  STOP*  MILES*         PURPOSE*  count
# 1          Fort Pierce     5.0              NaN      1
# ...

# %%
x1=miles_lt5['count'].sum()
miles_count.append(x1)

# %%
x1
# Out:
# 502

# %%
miles_5to10=df2.loc[((df2['MILES*'])>5) & ((df2['MILES*'])<=10)]

# %%
x2=miles_5to10['count'].sum()
miles_count.append(x2)

# %%
x2
# Out:
# 338

# %%
miles_10to15=df2.loc[((df2['MILES*'])>10) & ((df2['MILES*'])<=15)]

# %%
x3=miles_10to15['count'].sum()
miles_count.append(x3)

# %%
x3
# Out:
# 161

# %%
miles_15to20=df2.loc[((df2['MILES*'])>15) & ((df2['MILES*'])<=20)]

# %%
x4=miles_15to20['count'].sum()
miles_count.append(x4)

# %%
x4
# Out:
# 71

# %%
miles_gt20=df2.loc[((df2['MILES*'])>20)]

# %%
x5=miles_gt20['count'].sum()
miles_count.append(x5)

# %%
x5
# Out:
# 83

# %%
from matplotlib import style
style.use('ggplot')
plt.bar(miles_list,miles_count)
plt.title('Miles')

plt.xlabel('Miles Category')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
df2.groupby(['START*']).agg(['mean', 'sum'], ).head(10)

# %% [markdown]
# ## Relationship between the purpose and the no. of counts

# %%
df2['PURPOSE*'].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Commute              1
# Charity ($)          1
# Name: PURPOSE*, dtype: int64

# %%
sns.set(style='darkgrid')
plot=sns.countplot(df2['PURPOSE*'])
plot.set_xticklabels(plot.get_xticklabels(), rotation=40)
# Out:
# [Text(0, 0, 'Meal/Entertain'),
#  Text(0, 0, 'Errand/Supplies'),
#  Text(0, 0, 'Meeting'),
#  Text(0, 0, 'Customer Visit'),
#  Text(0, 0, 'Temporary Site'),
#  Text(0, 0, 'Between Offices'),
#  Text(0, 0, 'Charity ($)'),
#  Text(0, 0, 'Commute'),
#  Text(0, 0, 'Moving'),
#  Text(0, 0, 'Airport/Travel')]

# %% [markdown]
# ## Separating the start_date into date and time column
# Two columns are created as s_date and s_time

# %%
start_dt=[i.split(' ') for i in df2['START_DATE*'].tolist()]

# %%
start_dt
# Out:
# [['1/1/2016', '21:11'],
#  ['1/2/2016', '1:25'],
#  ['1/2/2016', '20:25'],
#  ['1/5/2016', '17:31'],
#  ['1/6/2016', '14:42'],
#  ['1/6/2016', '17:15'],
#  ['1/6/2016', '17:30'],
#  ['1/7/2016', '13:27'],
#  ['1/10/2016', '8:05'],
#  ['1/10/2016', '12:17'],
#  ['1/10/2016', '15:08'],
#  ['1/10/2016', '18:18'],
#  ['1/10/2016', '19:12'],
#  ['1/11/2016', '8:55'],
#  ['1/11/2016', '11:56'],
#  ['1/11/2016', '13:32'],
#  ['1/11/2016', '14:30'],
#  ['1/12/2016', '12:33'],
#  ['1/12/2016', '12:53'],
#  ['1/12/2016', '14:42'],
#  ['1/12/2016', '15:13'],
#  ['1/12/2016', '15:42'],
#  ['1/12/2016', '16:02'],
#  ['1/13/2016', '13:54'],
#  ['1/13/2016', '15:00'],
#  ['1/14/2016', '16:29'],
#  ['1/14/2016', '21:39'],
#  ['1/15/2016', '0:41'],
#  ['1/15/2016', '11:43'],
#  ['1/15/2016', '13:26'],
#  ['1/18/2016', '14:55'],
#  ['1/18/2016', '16:13'],
#  ['1/19/2016', '9:09'],
#  ['1/19/2016', '10:55'],
#  ['1/20/2016', '10:36'],
#  ['1/20/2016', '11:48'],
#  ['1/20/2016', '13:25'],
# ...

# %%
start=pd.DataFrame(start_dt)

# %%
start.columns=['s_date','s_time']

# %%
start
# Out:
#           s_date s_time
# 0       1/1/2016  21:11
# 1       1/2/2016   1:25
# 2       1/2/2016  20:25
# 3       1/5/2016  17:31
# 4       1/6/2016  14:42
# ...          ...    ...
# 1150  12/31/2016   1:07
# 1151  12/31/2016  13:24
# 1152  12/31/2016  15:03
# 1153  12/31/2016  21:32
# 1154  12/31/2016  22:08
#
# [1155 rows x 2 columns]

# %% [markdown]
# ## Similarly for the end_date two separate columns are created
# viz. e_date and e_time

# %%
end_dt=[i.split(' ') for i in df2['END_DATE*'].tolist()]

# %%
end=pd.DataFrame(end_dt)

# %%
end.columns=['e_date','e_time']

# %%
end
# Out:
#           e_date e_time
# 0       1/1/2016  21:17
# 1       1/2/2016   1:37
# 2       1/2/2016  20:38
# 3       1/5/2016  17:45
# 4       1/6/2016  15:49
# ...          ...    ...
# 1150  12/31/2016   1:14
# 1151  12/31/2016  13:42
# 1152  12/31/2016  15:38
# 1153  12/31/2016  21:50
# 1154  12/31/2016  23:51
#
# [1155 rows x 2 columns]

# %%
start_end=pd.concat([start,end], axis=1)

# %%
start_end
# Out:
#           s_date s_time      e_date e_time
# 0       1/1/2016  21:11    1/1/2016  21:17
# 1       1/2/2016   1:25    1/2/2016   1:37
# 2       1/2/2016  20:25    1/2/2016  20:38
# 3       1/5/2016  17:31    1/5/2016  17:45
# 4       1/6/2016  14:42    1/6/2016  15:49
# ...          ...    ...         ...    ...
# 1150  12/31/2016   1:07  12/31/2016   1:14
# 1151  12/31/2016  13:24  12/31/2016  13:42
# 1152  12/31/2016  15:03  12/31/2016  15:38
# 1153  12/31/2016  21:32  12/31/2016  21:50
# 1154  12/31/2016  22:08  12/31/2016  23:51
#
# [1155 rows x 4 columns]

# %%
df3=df2.iloc[:,2:7]

# %% [markdown]
# ## Concatinating the new columns and the existing columns in a new dataframe

# %%
new_df=pd.concat([start_end,df3],axis=1)

# %%
new_df
# Out:
#           s_date s_time      e_date e_time CATEGORY*            START*  \
# 0       1/1/2016  21:11    1/1/2016  21:17  Business       Fort Pierce
# 1       1/2/2016   1:25    1/2/2016   1:37  Business       Fort Pierce
# 2       1/2/2016  20:25    1/2/2016  20:38  Business       Fort Pierce
# 3       1/5/2016  17:31    1/5/2016  17:45  Business       Fort Pierce
# 4       1/6/2016  14:42    1/6/2016  15:49  Business       Fort Pierce
# ...          ...    ...         ...    ...       ...               ...
# 1150  12/31/2016   1:07  12/31/2016   1:14  Business           Kar?chi
# 1151  12/31/2016  13:24  12/31/2016  13:42  Business           Kar?chi
# 1152  12/31/2016  15:03  12/31/2016  15:38  Business  Unknown Location
# 1153  12/31/2016  21:32  12/31/2016  21:50  Business        Katunayake
# 1154  12/31/2016  22:08  12/31/2016  23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
new_df.isnull().sum()
# Out:
# s_date         0
# s_time         0
# e_date         0
# e_time         0
# CATEGORY*      0
# START*         0
# STOP*          0
# MILES*         0
# PURPOSE*     502
# dtype: int64

# %% [markdown]
# ## Converting to datetime.
# The start_date and End_date are in string format

# %%
new_df['s_date']=pd.to_datetime(new_df['s_date'],format="%m/%d/%Y")

# %%
new_df.dtypes
# Out:
# s_date       datetime64[ns]
# s_time               object
# e_date               object
# e_time               object
# CATEGORY*            object
# START*               object
# STOP*                object
# MILES*              float64
# PURPOSE*             object
# dtype: object

# %%
drives_pm=new_df['s_date'].dt.month.value_counts()   #For every month we are getting the no. of counts
drives_pm=drives_pm.sort_index()

# %%
drives_pm
# Out:
# 1      61
# 2     115
# 3     113
# 4      54
# 5      49
# 6     108
# 7     112
# 8     133
# 9      36
# 10    106
# 11    122
# 12    146
# Name: s_date, dtype: int64

# %% [markdown]
# ## Relationship between the months and the no. of counts.
# What is the no. of bookings for every month?

# %%
plt.figure(figsize=(15,10))
sns.countplot(new_df['s_date'].dt.month)
plt.xlabel('months')
# Out:
# Text(0.5, 0, 'months')

# %% [markdown]
# ## Relationship between start time and the no. of bookings

# %%
new_df['s_time']=pd.to_datetime(new_df['s_time'],format='%H:%M')

# %%
drives_ph=new_df['s_time'].dt.hour.value_counts()

# %%
drives_ph=drives_ph.sort_index()
drives_ph
# Out:
# 0     19
# 1      5
# 2      2
# 3      3
# 5      4
# 6      4
# 7     13
# 8     35
# 9     51
# 10    65
# 11    72
# 12    77
# 13    94
# 14    89
# 15    98
# 16    88
# 17    95
# 18    94
# 19    68
# 20    71
# 21    51
# 22    31
# 23    26
# Name: s_time, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(new_df['s_time'].dt.hour)
plt.xlabel('nth hour')
plt.ylabel('No. of bookings per hour')
# Out:
# Text(0, 0.5, 'No. of bookings per hour')

# %%
new_df['e_time']=pd.to_datetime(new_df['e_time'],format='%H:%M')

# %% [markdown]
# ## Calculating the travel time for every booking
# (in minutes)

# %%
travel_time=((new_df['e_time']-new_df['s_time']).dt.seconds)/60

# %%
travel_time
# Out:
# 0         6.0
# 1        12.0
# 2        13.0
# 3        14.0
# 4        67.0
#         ...
# 1150      7.0
# 1151     18.0
# 1152     35.0
# 1153     18.0
# 1154    103.0
# Length: 1155, dtype: float64

# %% [markdown]
# ## Relationship between miles and travel time

# %%
plt.figure(figsize=(20,10))
plt.plot(new_df['MILES*'],travel_time)

# %%
plt.figure(figsize=(20,10))
plt.scatter(new_df['MILES*'],travel_time,label='Miles vs Time',color='g')
plt.legend()
plt.xlabel('miles')
plt.ylabel('time')
# Out:
# Text(0, 0.5, 'time')

# %%
new_df['travel_time']=travel_time

# %%
new_df
# Out:
#          s_date              s_time      e_date              e_time CATEGORY*  \
# 0    2016-01-01 1900-01-01 21:11:00    1/1/2016 1900-01-01 21:17:00  Business
# 1    2016-01-02 1900-01-01 01:25:00    1/2/2016 1900-01-01 01:37:00  Business
# 2    2016-01-02 1900-01-01 20:25:00    1/2/2016 1900-01-01 20:38:00  Business
# 3    2016-01-05 1900-01-01 17:31:00    1/5/2016 1900-01-01 17:45:00  Business
# 4    2016-01-06 1900-01-01 14:42:00    1/6/2016 1900-01-01 15:49:00  Business
# ...         ...                 ...         ...                 ...       ...
# 1150 2016-12-31 1900-01-01 01:07:00  12/31/2016 1900-01-01 01:14:00  Business
# 1151 2016-12-31 1900-01-01 13:24:00  12/31/2016 1900-01-01 13:42:00  Business
# 1152 2016-12-31 1900-01-01 15:03:00  12/31/2016 1900-01-01 15:38:00  Business
# 1153 2016-12-31 1900-01-01 21:32:00  12/31/2016 1900-01-01 21:50:00  Business
# 1154 2016-12-31 1900-01-01 22:08:00  12/31/2016 1900-01-01 23:51:00  Business
#
# ...

# %%
sns.relplot(y='travel_time',x='MILES*',data=new_df, hue='PURPOSE*')

# %%
pur_miles=new_df.groupby(['PURPOSE*']).agg(sum).sort_values('MILES*', ascending=False)

# %%
pur_miles
# Out:
#                  MILES*  travel_time
# PURPOSE*
# Meeting          2851.3       5561.0
# Customer Visit   2089.5       3375.0
# Meal/Entertain    911.7       2580.0
# Temporary Site    523.7       1293.0
# Errand/Supplies   508.0       1661.0
# Between Offices   197.0        459.0
# Commute           180.2        185.0
# Moving             18.2         60.0
# Airport/Travel     16.5         78.0
# Charity ($)        15.1         27.0

# %%
pur_miles.reset_index(inplace=True)

# %%
pur_miles.columns=['PURPOSE*','MILES*','travel_time']

# %% [markdown]
# ## Relationship between Purpose and the miles travelled in each regard

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='MILES*',y='PURPOSE*',data=pur_miles)

# %%
place=df['START*'].value_counts()

# %%
place
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# College Avenue        1
# Jamestown Court       1
# South Berkeley        1
# North Austin          1
# Long Island City      1
# Name: START*, Length: 177, dtype: int64

# %%
group=df2.groupby(['START*']).agg( 'sum')  ##df2.groupby(['START*'])[['count']].sum()
group
# Out:
#                  MILES*  count
# START*
# Agnew              11.1      4
# Almond             15.2      1
# Apex               90.8     17
# Arabi              17.0      1
# Arlington           4.9      1
# ...                 ...    ...
# West University     4.4      2
# Weston              8.0      2
# Westpark Place     37.1     17
# Whitebridge       273.4     68
# Winston Salem     133.6      1
#
# [177 rows x 2 columns]

# %%
group=group.drop('MILES*', axis=1)
group
# Out:
#                  count
# START*
# Agnew                4
# Almond               1
# Apex                17
# Arabi                1
# Arlington            1
# ...                ...
# West University      2
# Weston               2
# Westpark Place      17
# Whitebridge         68
# Winston Salem        1
#
# [177 rows x 1 columns]

# %%
group.reset_index(inplace=True)

# %%
group
# Out:
#               START*  count
# 0              Agnew      4
# 1             Almond      1
# 2               Apex     17
# 3              Arabi      1
# 4          Arlington      1
# ..               ...    ...
# 172  West University      2
# 173           Weston      2
# 174   Westpark Place     17
# 175      Whitebridge     68
# 176    Winston Salem      1
#
# [177 rows x 2 columns]

# %%
group.columns
# Out:
# Index(['START*', 'count'], dtype='object')

# %%
group1=group.loc[group['count']>=10]

# %%
group1
# Out:
#                START*  count
# 2                Apex     17
# 10           Berkeley     16
# 17               Cary    201
# 34             Durham     37
# 45         Emeryville     10
# 67          Islamabad     57
# 74            Kar?chi     27
# 79             Kenner     11
# 81          Kissimmee     11
# 83             Lahore     36
# 101           Midtown     14
# 103       Morrisville     85
# 106       New Orleans     10
# 125        R?walpindi     11
# 126           Raleigh     28
# 162  Unknown Location    148
# 174    Westpark Place     17
# 175       Whitebridge     68

# %%
group2=group.loc[group['count']<10]
group2
# Out:
#                         START*  count
# 0                        Agnew      4
# 1                       Almond      1
# 3                        Arabi      1
# 4                    Arlington      1
# 5    Arlington Park at Amberly      1
# ..                         ...    ...
# 170                   West End      1
# 171            West Palm Beach      2
# 172            West University      2
# 173                     Weston      2
# 176              Winston Salem      1
#
# [159 rows x 2 columns]

# %%
group2['count'].sum()
# Out:
# 351

# %%
new_df1= pd.DataFrame({'START*':['Others(<10)'],'count': [group2['count'].sum()] })

# %%
new_df1
# Out:
#         START*  count
# 0  Others(<10)    351

# %%
group_final=pd.concat([group1,new_df1], axis=0)
group_final
# Out:
#                START*  count
# 2                Apex     17
# 10           Berkeley     16
# 17               Cary    201
# 34             Durham     37
# 45         Emeryville     10
# 67          Islamabad     57
# 74            Kar?chi     27
# 79             Kenner     11
# 81          Kissimmee     11
# 83             Lahore     36
# 101           Midtown     14
# 103       Morrisville     85
# 106       New Orleans     10
# 125        R?walpindi     11
# 126           Raleigh     28
# 162  Unknown Location    148
# 174    Westpark Place     17
# 175       Whitebridge     68
# 0         Others(<10)    351

# %%
group_final=group_final.sort_values('count',ascending=False)

# %% [markdown]
# ## Relationship between start city and the no. of counts
# Others(<10) refers to those 159 cities which has bookings less than 10 times

# %%
group_final
# Out:
#                START*  count
# 0         Others(<10)    351
# 17               Cary    201
# 162  Unknown Location    148
# 103       Morrisville     85
# 175       Whitebridge     68
# 67          Islamabad     57
# 34             Durham     37
# 83             Lahore     36
# 126           Raleigh     28
# 74            Kar?chi     27
# 174    Westpark Place     17
# 2                Apex     17
# 10           Berkeley     16
# 101           Midtown     14
# 81          Kissimmee     11
# 79             Kenner     11
# 125        R?walpindi     11
# 106       New Orleans     10
# 45         Emeryville     10

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='count',y='START*',data=group_final)
plt.ylabel('start city')
# Out:
# Text(0, 0.5, 'start city')
